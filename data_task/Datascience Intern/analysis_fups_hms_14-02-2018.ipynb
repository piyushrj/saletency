# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('fups_hms_14-02-18.xlsx', sheetname='Sheet1')

# %%
df.head()
# Out:
#   Allocated to  SL NO                               NAME OF THE HOSPITAL  \
# 0      Lakshya    211                             APEX HOSPITALS PVT LTD
# 1      Lakshya    213  APEX HOSPITAL(STEEL CITY CRITICAL CARE UNIT PV...
# 2      Lakshya    219  APOLLO BSR HOSPITALS(A UNIT OF BSR SUPERSPECIA...
# 3      Lakshya    208                                   ANUPAMA HOSPITAL
# 4      Lakshya      7                       AJHOSPITAL & RESEARCH CENTRE
#
#    Number Of Bed         Contact Name Designation    Contact Number  \
# 0            NaN         Mr.Rameshwar         NaN               NaN
# 1          100.0          Mr.Nagendra     Head IT       09866734910
# 2          175.0           Mr.Praveen     Head IT               NaN
# 3          100.0  Mr.Lakshmipati Raju         NaN               NaN
# 4          350.0    Sharada J. Shetty    Director  +91 824 222 5533
#
#                         Email                               ADDRESS-1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 19 columns):
# Allocated to            6 non-null object
# SL NO                   6 non-null int64
# NAME OF THE HOSPITAL    6 non-null object
# Number Of Bed           5 non-null float64
# Contact Name            6 non-null object
# Designation             4 non-null object
# Contact Number          3 non-null object
# Email                   2 non-null object
# ADDRESS-1               6 non-null object
# ADDRESS-2               6 non-null object
# CITY                    6 non-null object
# DISTRICT                6 non-null object
# STATE                   6 non-null object
# PINCODE                 6 non-null int64
# STD CODE                6 non-null int64
# PHONE NO.               6 non-null object
# Status                  2 non-null object
# Remarks                 6 non-null object
# Case                    1 non-null object
# dtypes: float64(1), int64(3), object(15)
# ...

# %% [markdown]
# This sheet contains only 6 data points and also includes null values, very few data points to perform a conclusive analysis.
